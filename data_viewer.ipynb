# %%
import json
import pandas as pd

# %%
json_path="combined_job_naukri_data.json"
job_df = pd.read_json(json_path)

# %%
job_df.head()
# Out:
#                                            job_title  \
# 0  Chatbot, Machine Learning and Artificial Intel...
# 1  Senior Engineer – Artificial Intelligence / Co...
# 2                   Artificial Intelligence Engineer
# 3          Artificial Intelligence Software Engineer
# 4  Artificial Intelligence/Machine Learning Engin...
#
#                                         company_name company_rating  \
# 0                                           P2F Semi      Not Found
# 1                            SuccessR Hrtech Pvt Ltd            4.2
# 2  NAYAN INDIA SCIENCE AND TECHNOLOGIES PRIVATE L...            4.8
# 3                              Acorre Energy Sdn Bhd      Not Found
# 4                                      Serving Skill      Not Found
#
#   company_review_count experience                   salary  \
# 0            Not Found    2-4 Yrs            Not disclosed
# 1          (3 Reviews)    3-7 Yrs            Not disclosed
# ...

# %%
job_df.count()
# Out:
# job_title               27999
# company_name            27999
# company_rating          27999
# company_review_count    27999
# experience              27999
# salary                  27999
# location                27999
# job_description         27999
# job_tags                27999
# dtype: int64

# %%
json_path="processed_naukri_job_data.json"
processed_job_df = pd.read_json(json_path)

# %%
processed_job_df.head()
# Out:
#                                       job_title  \
# 59             Senior Machine Learning Engineer
# 60                Sr. Project Engineer - AI /ML
# 62  Senior AI and ML - Computer Vision Engineer
# 67                               Ai Ml Engineer
# 72                    Machine learning Engineer
#
#                                          company_name  company_rating  \
# 59                        Aimonk Labs Private Limited             4.3
# 60  IDRBT - Institute for Development and Research...             4.8
# 62                               Diycam India Pvt Ltd             3.7
# 67                                     Namaste Credit             3.8
# 72                          The Fastest Media Company             4.7
#
#    company_review_count experience                     salary  \
# 59          (3 Reviews)    2-7 Yrs   5,00,000 - 15,00,000 PA.
# 60         (17 Reviews)    2-5 Yrs  10,00,000 - 12,00,000 PA.
# ...

# %%
processed_job_df.count()
# Out:
# job_title                       1397
# company_name                    1397
# company_rating                  1397
# company_review_count            1397
# experience                      1397
# salary                          1397
# location                        1397
# job_description                 1397
# job_tags                        1397
# updated_company_review_count    1397
# updated_company_rating          1397
# average_salary                  1397
# dtype: int64
